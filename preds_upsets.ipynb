# %% [markdown]
# # March Machine Learning Mania
# In this notebook, we:
# - Attempt to predict the number of upsets in a following round based on the number of upsets that have occurred so far in a NCAA tournament.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from gc import collect
import os
import sys
from tqdm import tqdm

from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.svm import SVR, SVC
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.neural_network import MLPRegressor, MLPClassifier
from sklearn.metrics import mean_squared_error, r2_score, log_loss, accuracy_score, confusion_matrix, classification_report
from xgboost import XGBRegressor, XGBClassifier

# display 100 rows and 100 columns
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# global random seed
SEED = 0

# set numpy seed
np.random.seed(SEED)

# %% [markdown]
# ## Load Data

# %%
# root dirs
root = 'data/'
mroot = 'data/mens/'
wroot = 'data/womens/'

# load in features compact
upsets = pd.read_csv(root + 'processed/upsets.csv').sort_values(['Season', 'Round'])

# check
upsets.head(12)
# Out:
#     Season  Round  Pct_upsets  Avg_seed_diff  Std_seed_diff  Avg_seed  \
# 0     2003      1      0.2500      -3.750000       3.011881    8.5000
# 1     2003      2      0.3750      -4.333333       3.204164    5.4375
# 2     2003      3      0.2500      -1.000000       0.000000    4.1875
# 3     2003      4      0.7500      -1.666667       0.577350    2.3750
# 4     2003      5      0.5000      -2.000000       0.000000    2.2500
# 5     2003      6      1.0000      -1.000000       0.000000    2.5000
# 6     2004      1      0.1250      -4.500000       3.000000    8.5000
# 7     2004      2      0.4375      -4.714286       3.093773    5.0625
# 8     2004      3      0.2500      -3.500000       0.707107    4.5625
# 9     2004      4      0.2500      -1.000000       0.000000    3.5000
# 10    2004      5      1.0000      -1.000000       0.000000    2.0000
# 11    2004      6      0.0000       0.000000       0.000000    2.5000
#
#     Std_seed Tournament
# 0   4.609772          M
# 1   3.445445          M
# 2   3.186274          M
# 3   1.932453          M
# 4   0.829156          M
# 5   0.500000          M
# 6   4.609772          M
# 7   3.071416          M
# 8   2.691857          M
# 9   2.500000          M
# 10  0.707107          M
# 11  0.500000          M

# %% [markdown]
# ## Create Labels

# %%
# label is pct of upsets in next round
upsets['target'] = upsets['Pct_upsets'].shift(-1)

# check
upsets.head(12)
# Out:
#     Season  Round  Pct_upsets  Avg_seed_diff  Std_seed_diff  Avg_seed  \
# 0     2003      1      0.2500      -3.750000       3.011881    8.5000
# 1     2003      2      0.3750      -4.333333       3.204164    5.4375
# 2     2003      3      0.2500      -1.000000       0.000000    4.1875
# 3     2003      4      0.7500      -1.666667       0.577350    2.3750
# 4     2003      5      0.5000      -2.000000       0.000000    2.2500
# 5     2003      6      1.0000      -1.000000       0.000000    2.5000
# 6     2004      1      0.1250      -4.500000       3.000000    8.5000
# 7     2004      2      0.4375      -4.714286       3.093773    5.0625
# 8     2004      3      0.2500      -3.500000       0.707107    4.5625
# 9     2004      4      0.2500      -1.000000       0.000000    3.5000
# 10    2004      5      1.0000      -1.000000       0.000000    2.0000
# 11    2004      6      0.0000       0.000000       0.000000    2.5000
#
#     Std_seed Tournament  target
# 0   4.609772          M  0.3750
# 1   3.445445          M  0.2500
# 2   3.186274          M  0.7500
# 3   1.932453          M  0.5000
# 4   0.829156          M  1.0000
# 5   0.500000          M  0.1250
# 6   4.609772          M  0.4375
# 7   3.071416          M  0.2500
# 8   2.691857          M  0.2500
# 9   2.500000          M  1.0000
# 10  0.707107          M  0.0000
# 11  0.500000          M  0.2500

# %%
# drop round 6 rows (no target)
upsets = upsets[upsets['Round'] != 6]

# check
upsets.head(10)
# Out:
#     Season  Round  Pct_upsets  Avg_seed_diff  Std_seed_diff  Avg_seed  \
# 0     2003      1      0.2500      -3.750000       3.011881    8.5000
# 1     2003      2      0.3750      -4.333333       3.204164    5.4375
# 2     2003      3      0.2500      -1.000000       0.000000    4.1875
# 3     2003      4      0.7500      -1.666667       0.577350    2.3750
# 4     2003      5      0.5000      -2.000000       0.000000    2.2500
# 6     2004      1      0.1250      -4.500000       3.000000    8.5000
# 7     2004      2      0.4375      -4.714286       3.093773    5.0625
# 8     2004      3      0.2500      -3.500000       0.707107    4.5625
# 9     2004      4      0.2500      -1.000000       0.000000    3.5000
# 10    2004      5      1.0000      -1.000000       0.000000    2.0000
#
#     Std_seed Tournament  target
# 0   4.609772          M  0.3750
# 1   3.445445          M  0.2500
# 2   3.186274          M  0.7500
# 3   1.932453          M  0.5000
# 4   0.829156          M  1.0000
# 6   4.609772          M  0.4375
# 7   3.071416          M  0.2500
# 8   2.691857          M  0.2500
# 9   2.500000          M  1.0000
# 10  0.707107          M  0.0000

# %% [markdown]
# ## Predictions

# %%
# split data
mupsets = upsets[upsets['Tournament'] == 'M']
wupsets = upsets[upsets['Tournament'] == 'W']

# %% [markdown]
# ### Data Preprocessing

# %%
def run_model(tournament, estimator, data, features, models_df, scaler=None, folds=5):
    """
    Run a model on data and save results to models_df.

    Parameters
    ----------
    tournament : str
        'M' or 'W'.
    estimator : sklearn estimator
        Estimator to use for modeling.
    data : pd.DataFrame
        Data to model.
    features : list
        Feature subset to use for modeling.
    models_df : pd.DataFrame
        DataFrame to save results to.
    scaler : sklearn scaler, optional
        Scaler to use for data. Default is None.
    folds : int
        Number of cross-validation folds to use.

    Returns
    -------
    None
    """
    
    # create copy to avoid modification
    data = data.copy()

    # drop unused cols
    data = data.drop(columns=['Season', 'Tournament'])

    # define cross-validation
    kf = KFold(n_splits=folds, shuffle=True, random_state=SEED)

    # define X and y
    X = data[features]
    y = data['target']

    # initialize lists to store metrics
    rmse_scores_train = []
    rmse_scores_test = []
    r2_scores_train = []
    r2_scores_test = []
    acc_scores_train = []
    acc_scores_test = []

    for train_index, test_index in kf.split(X):
        # split data
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # scale data
        if scaler:
            X_train = scaler.fit_transform(X_train)
            X_test = scaler.transform(X_test)

        # fit model
        model = estimator.fit(X_train, y_train)

        # make predictions
        train_preds = model.predict(X_train)
        test_preds = model.predict(X_test)

        # calculate metrics
        rmse_scores_train.append(np.sqrt(mean_squared_error(y_train, train_preds)))
        rmse_scores_test.append(np.sqrt(mean_squared_error(y_test, test_preds)))
        r2_scores_train.append(r2_score(y_train, train_preds))
        r2_scores_test.append(r2_score(y_test, test_preds))

    # save results
    models_df.loc[len(models_df.index)] = [tournament, estimator, scaler, features, folds, np.mean(rmse_scores_train), np.mean(rmse_scores_test), np.mean(r2_scores_train), np.mean(r2_scores_test)]

    # delete variables
    del data, X, y, kf, X_train, X_test, y_train, y_test, model, train_preds, test_preds
    
    return

# %% [markdown]
# ### Men's

# %%
# create a df to hold performance metrics
upset_preds = pd.DataFrame(columns=['Tournament', 'Model', 'Scaler', 'Features', 'Num_CV_Folds', 'Train_RMSE', 'Val_RMSE', 'Train_R2', 'Val_R2'])

# load upset_preds df
# upset_preds = pd.read_csv('models/upset_preds.csv')

# %%
# define regression models
models = [LinearRegression(n_jobs=-1), RandomForestRegressor(n_jobs=-1), XGBRegressor(n_jobs=-1), SVR(), KNeighborsRegressor(n_jobs=-1)]
scalers = [None, StandardScaler(), MinMaxScaler()]
feature_subsets = [['Round', 'Pct_upsets', 'Avg_seed_diff', 'Std_seed_diff', 'Avg_seed', 'Std_seed'], ['Round', 'Pct_upsets', 'Avg_seed_diff', 'Std_seed_diff']]

# run regression models
for model in tqdm(models, desc='Model', file=sys.stdout):
    for scaler in scalers:
        for features in feature_subsets:
            for fold in [3, 6, 9]:
                # run model
                run_model(tournament='M', estimator=model, data=mupsets, features=features, models_df=upset_preds, scaler=scaler, folds=fold)
# Out:
# Model: 100%|██████████| 5/5 [00:34<00:00,  6.94s/it]

# %%
# inspect
upset_preds[upset_preds['Tournament'] == 'M'].sort_values(by='Val_RMSE', ascending=False).head()
# Out:
#    Tournament  Model            Scaler  \
# 70          M  SVR()    MinMaxScaler()
# 64          M  SVR()  StandardScaler()
# 69          M  SVR()    MinMaxScaler()
# 71          M  SVR()    MinMaxScaler()
# 58          M  SVR()              None
#
#                                       Features  Num_CV_Folds  Train_RMSE  \
# 70  [Pct_upsets, Avg_seed_diff, Std_seed_diff]             6    0.250775
# 64  [Pct_upsets, Avg_seed_diff, Std_seed_diff]             6    0.245539
# 69  [Pct_upsets, Avg_seed_diff, Std_seed_diff]             3    0.245441
# 71  [Pct_upsets, Avg_seed_diff, Std_seed_diff]             9    0.252381
# 58  [Pct_upsets, Avg_seed_diff, Std_seed_diff]             6    0.262521
#
#     Val_RMSE  Train_R2    Val_R2
# 70  0.300734  0.013023 -0.633954
# 64  0.298828  0.053546 -0.609231
# 69  0.291431  0.057558 -0.352699
# 71  0.291012  0.004603 -0.558221
# 58  0.288065 -0.080753 -0.453554

# %%
upset_preds
# Out:
#    Tournament                                              Model  \
# 0           M                        LinearRegression(n_jobs=-1)
# 1           M                        LinearRegression(n_jobs=-1)
# 2           M                        LinearRegression(n_jobs=-1)
# 3           M                        LinearRegression(n_jobs=-1)
# 4           M                        LinearRegression(n_jobs=-1)
# 5           M                        LinearRegression(n_jobs=-1)
# 6           M                        LinearRegression(n_jobs=-1)
# 7           M                        LinearRegression(n_jobs=-1)
# 8           M                        LinearRegression(n_jobs=-1)
# 9           M                        LinearRegression(n_jobs=-1)
# 10          M                        LinearRegression(n_jobs=-1)
# 11          M                        LinearRegression(n_jobs=-1)
# 12          M                        LinearRegression(n_jobs=-1)
# 13          M                        LinearRegression(n_jobs=-1)
# 14          M                        LinearRegression(n_jobs=-1)
# 15          M                        LinearRegression(n_jobs=-1)
# 16          M                        LinearRegression(n_jobs=-1)
# 17          M                        LinearRegression(n_jobs=-1)
# 18          M  (DecisionTreeRegressor(max_features='auto', ra...
# 19          M  (DecisionTreeRegressor(max_features='auto', ra...
# 20          M  (DecisionTreeRegressor(max_features='auto', ra...
# 21          M  (DecisionTreeRegressor(max_features='auto', ra...
# 22          M  (DecisionTreeRegressor(max_features='auto', ra...
# 23          M  (DecisionTreeRegressor(max_features='auto', ra...
# 24          M  (DecisionTreeRegressor(max_features='auto', ra...
# 25          M  (DecisionTreeRegressor(max_features='auto', ra...
# 26          M  (DecisionTreeRegressor(max_features='auto', ra...
# 27          M  (DecisionTreeRegressor(max_features='auto', ra...
# 28          M  (DecisionTreeRegressor(max_features='auto', ra...
# 29          M  (DecisionTreeRegressor(max_features='auto', ra...
# 30          M  (DecisionTreeRegressor(max_features='auto', ra...
# 31          M  (DecisionTreeRegressor(max_features='auto', ra...
# 32          M  (DecisionTreeRegressor(max_features='auto', ra...
# 33          M  (DecisionTreeRegressor(max_features='auto', ra...
# 34          M  (DecisionTreeRegressor(max_features='auto', ra...
# 35          M  (DecisionTreeRegressor(max_features='auto', ra...
# 36          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 37          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 38          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 39          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 40          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 41          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 42          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 43          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 44          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 45          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 46          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 47          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 48          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 49          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 50          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 51          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 52          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 53          M  XGBRegressor(base_score=0.5, booster='gbtree',...
# 54          M                                              SVR()
# 55          M                                              SVR()
# 56          M                                              SVR()
# 57          M                                              SVR()
# 58          M                                              SVR()
# 59          M                                              SVR()
# 60          M                                              SVR()
# 61          M                                              SVR()
# 62          M                                              SVR()
# 63          M                                              SVR()
# 64          M                                              SVR()
# 65          M                                              SVR()
# 66          M                                              SVR()
# 67          M                                              SVR()
# 68          M                                              SVR()
# 69          M                                              SVR()
# 70          M                                              SVR()
# 71          M                                              SVR()
# 72          M                     KNeighborsRegressor(n_jobs=-1)
# 73          M                     KNeighborsRegressor(n_jobs=-1)
# 74          M                     KNeighborsRegressor(n_jobs=-1)
# 75          M                     KNeighborsRegressor(n_jobs=-1)
# 76          M                     KNeighborsRegressor(n_jobs=-1)
# 77          M                     KNeighborsRegressor(n_jobs=-1)
# 78          M                     KNeighborsRegressor(n_jobs=-1)
# 79          M                     KNeighborsRegressor(n_jobs=-1)
# 80          M                     KNeighborsRegressor(n_jobs=-1)
# 81          M                     KNeighborsRegressor(n_jobs=-1)
# 82          M                     KNeighborsRegressor(n_jobs=-1)
# 83          M                     KNeighborsRegressor(n_jobs=-1)
# 84          M                     KNeighborsRegressor(n_jobs=-1)
# 85          M                     KNeighborsRegressor(n_jobs=-1)
# 86          M                     KNeighborsRegressor(n_jobs=-1)
# 87          M                     KNeighborsRegressor(n_jobs=-1)
# 88          M                     KNeighborsRegressor(n_jobs=-1)
# 89          M                     KNeighborsRegressor(n_jobs=-1)
#
#               Scaler                                           Features  \
# 0               None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 1               None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 2               None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 3               None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 4               None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 5               None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 6   StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 7   StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 8   StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 9   StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 10  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 11  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 12    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 13    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 14    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 15    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 16    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 17    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 18              None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 19              None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 20              None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 21              None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 22              None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 23              None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 24  StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 25  StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 26  StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 27  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 28  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 29  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 30    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 31    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 32    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 33    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 34    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 35    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 36              None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 37              None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 38              None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 39              None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 40              None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 41              None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 42  StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 43  StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 44  StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 45  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 46  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 47  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 48    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 49    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 50    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 51    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 52    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 53    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 54              None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 55              None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 56              None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 57              None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 58              None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 59              None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 60  StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 61  StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 62  StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 63  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 64  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 65  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 66    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 67    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 68    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 69    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 70    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 71    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 72              None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 73              None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 74              None  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 75              None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 76              None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 77              None         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 78  StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 79  StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 80  StandardScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 81  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 82  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 83  StandardScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 84    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 85    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 86    MinMaxScaler()  [Pct_upsets, Avg_seed_diff, Std_seed_diff, Avg...
# 87    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 88    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
# 89    MinMaxScaler()         [Pct_upsets, Avg_seed_diff, Std_seed_diff]
#
#     Num_CV_Folds  Train_RMSE  Val_RMSE  Train_R2    Val_R2
# 0              3    0.243946  0.268300  0.069308 -0.133886
# 1              6    0.246183  0.263354  0.052075 -0.199196
# 2              9    0.247018  0.254722  0.047425 -0.149606
# 3              3    0.248812  0.259653  0.031906 -0.062198
# 4              6    0.249450  0.259144  0.026765 -0.156977
# 5              9    0.250169  0.250284  0.022919 -0.127606
# 6              3    0.243946  0.268300  0.069308 -0.133886
# 7              6    0.246183  0.263354  0.052075 -0.199196
# 8              9    0.247018  0.254722  0.047425 -0.149606
# 9              3    0.248812  0.259653  0.031906 -0.062198
# 10             6    0.249450  0.259144  0.026765 -0.156977
# 11             9    0.250169  0.250284  0.022919 -0.127606
# 12             3    0.243946  0.268300  0.069308 -0.133886
# 13             6    0.246183  0.263354  0.052075 -0.199196
# 14             9    0.247018  0.254722  0.047425 -0.149606
# 15             3    0.248812  0.259653  0.031906 -0.062198
# 16             6    0.249450  0.259144  0.026765 -0.156977
# 17             9    0.250169  0.250284  0.022919 -0.127606
# 18             3    0.089908  0.237131  0.872528  0.109355
# 19             6    0.092987  0.218163  0.864494  0.164515
# 20             9    0.089337  0.219536  0.875072 -0.038644
# 21             3    0.185050  0.258429  0.460506 -0.052690
# 22             6    0.186329  0.256788  0.455837 -0.157510
# 23             9    0.186129  0.241953  0.458472 -0.079502
# 24             3    0.091619  0.238775  0.867689  0.094634
# 25             6    0.091610  0.223376  0.868714  0.111024
# 26             9    0.090850  0.216701  0.870734  0.015310
# 27             3    0.183686  0.264611  0.468418 -0.104134
# 28             6    0.186535  0.262305  0.454741 -0.220739
# 29             9    0.186917  0.249344  0.453962 -0.133277
# 30             3    0.094568  0.245836  0.859726  0.042480
# 31             6    0.091831  0.223771  0.867877  0.126321
# 32             9    0.092073  0.222117  0.867549  0.005963
# 33             3    0.183646  0.266819  0.468233 -0.122977
# 34             6    0.186103  0.264961  0.457280 -0.230043
# 35             9    0.187438  0.247011  0.450709 -0.136507
# 36             3    0.001262  0.275580  0.999975 -0.204439
# 37             6    0.001309  0.239103  0.999973 -0.002678
# 38             9    0.001278  0.248734  0.999974 -0.288957
# 39             3    0.171173  0.269350  0.535189 -0.143768
# 40             6    0.175895  0.273506  0.514629 -0.330647
# 41             9    0.176696  0.259549  0.511677 -0.330419
# 42             3    0.001262  0.263873  0.999975 -0.097904
# 43             6    0.001309  0.238958  0.999973 -0.001820
# 44             9    0.001278  0.248764  0.999974 -0.289407
# 45             3    0.171173  0.268406  0.535189 -0.135648
# 46             6    0.175895  0.273482  0.514629 -0.330456
# 47             9    0.176696  0.259580  0.511677 -0.330623
# 48             3    0.001262  0.274783  0.999975 -0.197760
# 49             6    0.001309  0.238829  0.999973 -0.000334
# 50             9    0.001278  0.248370  0.999974 -0.286245
# 51             3    0.171173  0.269338  0.535189 -0.143668
# 52             6    0.175895  0.273492  0.514629 -0.330524
# 53             9    0.176696  0.259572  0.511677 -0.331199
# 54             3    0.232339  0.260359  0.153609 -0.077660
# 55             6    0.236195  0.256324  0.127193 -0.118841
# 56             9    0.237239  0.257793  0.120716 -0.245322
# 57             3    0.256786  0.282856 -0.031273 -0.267089
# 58             6    0.262521  0.288065 -0.080753 -0.453554
# 59             9    0.267805  0.278115 -0.119795 -0.360201
# 60             3    0.189218  0.260232  0.435183 -0.074008
# 61             6    0.190660  0.250742  0.429399 -0.141321
# 62             9    0.192415  0.241605  0.421317 -0.128239
# 63             3    0.242319  0.283867  0.080951 -0.279754
# 64             6    0.245539  0.298828  0.053546 -0.609231
# 65             9    0.245226  0.284643  0.060019 -0.507564
# 66             3    0.200309  0.270692  0.369414 -0.161944
# 67             6    0.201752  0.250690  0.361620 -0.135990
# 68             9    0.203284  0.247613  0.353991 -0.160909
# 69             3    0.245441  0.291431  0.057558 -0.352699
# 70             6    0.250775  0.300734  0.013023 -0.633954
# 71             9    0.252381  0.291012  0.004603 -0.558221
# 72             3    0.209107  0.240199  0.312260  0.086213
# 73             6    0.210004  0.232629  0.308119  0.028962
# 74             9    0.207114  0.240921  0.329612 -0.086539
# 75             3    0.243745  0.279274  0.070005 -0.234180
# 76             6    0.247824  0.273729  0.027112 -0.328165
# 77             9    0.243205  0.273983  0.074019 -0.401789
# 78             3    0.219836  0.269245  0.242154 -0.145370
# 79             6    0.215687  0.256320  0.270807 -0.225053
# 80             9    0.215509  0.251489  0.274296 -0.181127
# 81             3    0.245964  0.286102  0.051577 -0.297318
# 82             6    0.240713  0.279641  0.092945 -0.405903
# 83             9    0.246855  0.279462  0.048654 -0.553803
# 84             3    0.217397  0.265975  0.259445 -0.118686
# 85             6    0.213211  0.252640  0.287300 -0.197950
# 86             9    0.213988  0.251008  0.284447 -0.166136
# 87             3    0.244114  0.276216  0.067526 -0.211033
# 88             6    0.240417  0.276865  0.095607 -0.477029
# 89             9    0.242907  0.267890  0.078459 -0.480772

# %% [markdown]
# ### Women's

# %%
# run regression models
for model in tqdm(models, desc='Model', file=sys.stdout):
    for scaler in scalers:
        for features in feature_subsets:
            for fold in [3, 6, 9]:
                # run model
                run_model(tournament='W', estimator=model, data=wupsets, features=features, models_df=upset_preds, scaler=scaler, folds=fold)
# Out:
# Model: 100%|██████████| 5/5 [00:35<00:00,  7.00s/it]

# %%
# inspect
upset_preds[upset_preds['Tournament'] == 'W'].sort_values(by='Val_RMSE', ascending=False).head()
# Out:
#    Tournament             Label                        Model  Num_Features  \
# 80          M  A_adj_score_diff  LinearRegression(n_jobs=-1)            67
# 0           M  A_adj_score_diff  LinearRegression(n_jobs=-1)            70
# 60          M  A_adj_score_diff  LinearRegression(n_jobs=-1)            69
# 20          M  A_adj_score_diff  LinearRegression(n_jobs=-1)            68
# 40          M  A_adj_score_diff  LinearRegression(n_jobs=-1)            67
#
#                                              Features  Num_CV_Folds  Train_R2  \
# 80  ['A_1_pos_game_ratio', 'A_1_pos_loss_missing',...             5  0.429856
# 0   ['A_1_pos_game_ratio', 'A_1_pos_loss_missing',...             5  0.431068
# 60  ['A_1_pos_game_ratio', 'A_1_pos_loss_missing',...             5  0.430107
# 20  ['A_1_pos_game_ratio', 'A_1_pos_loss_missing',...             5  0.430615
# 40  ['A_1_pos_game_ratio', 'A_1_pos_loss_missing',...             5  0.426528
#
#       Val_R2  Train_RMSE   Val_RMSE  Train_Acc   Val_Acc  Val_r1_acc  \
# 80  0.239511   11.045665  11.701572   0.724928  0.704560    0.742861
# 0   0.232711   11.033918  11.749827   0.725868  0.702054    0.741293
# 60  0.235875   11.043223  11.729381   0.724301  0.702054    0.740778
# 20  0.232794   11.038220  11.750188   0.724405  0.699541    0.741371
# 40  0.235529   11.078017  11.735523   0.723674  0.698284    0.739631
#
#     Val_r2_acc  Val_r3_acc  Val_r4_acc  Val_r5_acc  Val_r6_acc
# 80    0.690977    0.684622    0.560981    0.612601    0.636825
# 0     0.677911    0.693672    0.568981    0.599267    0.670159
# 60    0.681194    0.690814    0.554085    0.612601    0.670159
# 20    0.679361    0.683224    0.552981    0.568498    0.670159
# 40    0.674414    0.689038    0.563176    0.570549    0.647937

# %%
# save reg_df
reg_df.to_csv('models/regression_models.csv', index=False)

# %% [markdown]
# - After manual model inspection, Linear Regression performed the best when we replaced the seed with seed_win_prob and used the team A/B data.
